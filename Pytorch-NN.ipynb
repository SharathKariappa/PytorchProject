# %% [markdown]
# <a href="https://colab.research.google.com/github/SharathKariappa/PytorchProject/blob/GoogleColab_Pytorch/Pytorch-NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s
